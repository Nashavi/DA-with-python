# %%
import pandas as pd

# %%
df = pd.read_csv('data/MonthlySales.csv')

# %%
df
# Out:
#          month      sales
# 0   2013-01-01   14236.90
# 1   2013-02-01    4519.89
# 2   2013-03-01   55691.01
# 3   2013-04-01   28295.35
# 4   2013-05-01   23648.29
# 5   2013-06-01   34595.13
# 6   2013-07-01   33946.39
# 7   2013-08-01   27909.47
# 8   2013-09-01   81777.35
# 9   2013-10-01   31453.39
# 10  2013-11-01   78628.72
# 11  2013-12-01   69545.62
# 12  2014-01-01   18174.08
# 13  2014-02-01   11951.41
# 14  2014-03-01   38726.25
# 15  2014-04-01   34195.21
# 16  2014-05-01   30131.69
# 17  2014-06-01   24797.29
# 18  2014-07-01   28765.33
# 19  2014-08-01   36898.33
# 20  2014-09-01   64595.92
# 21  2014-10-01   31404.92
# 22  2014-11-01   75972.56
# 23  2014-12-01   74919.52
# 24  2015-01-01   18542.49
# 25  2015-02-01   22867.71
# 26  2015-03-01   51186.22
# 27  2015-04-01   39248.59
# 28  2015-05-01   56691.08
# 29  2015-06-01   39430.44
# 30  2015-07-01   38440.76
# 31  2015-08-01   33265.56
# 32  2015-09-01   72908.11
# 33  2015-10-01   56463.13
# 34  2015-11-01   82192.32
# 35  2015-12-01   97237.42
# 36  2016-01-01   44703.14
# 37  2016-02-01   20301.13
# 38  2016-03-01   58872.35
# 39  2016-04-01   36521.54
# 40  2016-05-01   44261.11
# 41  2016-06-01   52981.73
# 42  2016-07-01   45264.42
# 43  2016-08-01   63120.89
# 44  2016-09-01   87866.65
# 45  2016-10-01   77776.92
# 46  2016-11-01  118447.83
# 47  2016-12-01   83829.32

# %%
import json
from pandas.io.json import json_normalize

with open('data/monthlySalesbyCategoryMultiple.json') as json_data:
    d = json.load(json_data)

# %%
df = json_normalize(d['contents'], 'monthlySales', ['category', 'region'])

# %%
df
# Out:
#        month  sales    category region
# 0   20130101     38   Furniture   West
# 1   20130201     35   Furniture   West
# 2   20130301     41   Furniture   West
# 3   20130401     55   Furniture   West
# 4   20130501     58   Furniture   West
# 5   20130601     66   Furniture   West
# 6   20130701     74   Furniture   West
# 7   20130801     78   Furniture   West
# 8   20130901     38   Furniture   West
# 9   20131001     30   Furniture   West
# 10  20131101     26   Furniture   West
# 11  20131201     29   Furniture   West
# 12  20130101     54  Technology   West
# 13  20130201     66  Technology   West
# 14  20130301     77  Technology   West
# 15  20130401     70  Technology   West
# 16  20130501     60  Technology   West
# 17  20130601     63  Technology   West
# 18  20130701     55  Technology   West
# 19  20130801     47  Technology   West
# 20  20130901     55  Technology   West
# 21  20131001     30  Technology   West
# 22  20131101     22  Technology   West
# 23  20131201     77  Technology   West

# %%
#reading parquet into panda dataframe
import pyarrow.parquet as pq

# %%
table = pq.read_table('data/MonthlyProductSales.parquet')

# %%
table.to_pandas()
# Out:
#      Month of Order Date                                       Product Name  \
# 0          b'2017-01-13'                                      b'Xerox 1972'
# 1          b'2017-01-13'                                      b'Xerox 1923'
# 2          b'2017-01-13'                                       b'Xerox 225'
# 3          b'2017-01-13'                                       b'Xerox 195'
# 4          b'2017-01-13'  b'Wireless Extenders zBoost YX545 SOHO Signal ...
# 9240       b'2017-12-16'  b'Acco Four Pocket Poly Ring Binder with Label...
# 9241       b'2017-12-16'    b'Acco Economy Flexible Poly Round Ring Binder'
# 9242       b'2017-12-16'  b'Acco Data Flex Cable Posts For Top & Bottom ...
# 9243       b'2017-12-16'              b'Acco Banker\'s Clasps, 5 3/4"-Long'
# 9244       b'2017-12-16'  b'Acco 6 Outlet Guardian Premium Plus Surge Su...
# 9245       b'2017-12-16'                               b'Acco 3-Hole Punch'
# 9246       b'2017-12-16'         b'#10- 4 1/8" x 9 1/2" Recycled Envelopes'
# 9247       b'2017-12-16'    b'14-7/8 x 11 Blue Bar Computer Printout Paper'
# 9248       b'2017-12-16'                    b'6" Cubicle Wall Clock, Black'
# 9249       b'2017-12-16'                b'3M Hangers With Command Adhesive'
# 9250       b'2017-12-16'  b'3.6 Cubic Foot Counter Height Office Refrige...
# 9251       b'2017-12-16'                              b'3-ring staple pack'
#
#       Sales
# 0        11
# 1        37
# 2        19
# 3        40
# 4       756
# 5        19
# 6        11
# 7        15
# 8        25
# 9       109
# 10       56
# 11     1326
# 12       30
# 13       35
# 14      230
# 15        7
# 16      291
# 17       62
# 18      142
# 19      490
# 20      273
# 21       30
# 22        5
# 23       17
# 24       57
# 25        4
# 26      647
# 27       44
# 28      334
# 29      181
# ...     ...
# 9222     37
# 9223     30
# 9224     62
# 9225     52
# 9226      9
# 9227    302
# 9228     33
# 9229   1270
# 9230     12
# 9231     28
# 9232      9
# 9233     26
# 9234     70
# 9235      6
# 9236     13
# 9237      8
# 9238     15
# 9239     20
# 9240     18
# 9241      3
# 9242     33
# 9243     17
# 9244     29
# 9245     18
# 9246     44
# 9247     96
# 9248     10
# 9249     10
# 9250    295
# 9251      9
#
# [9252 rows x 3 columns]

# %%
# you need to install html5lib
# pip install html5lib
# reading data from a html site
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations')

# %%
# get part that has the states and abbreviations
df_usa = df[0]

# %%
# remove unnecessary rows and columns
final_df = df_usa.drop(df_usa.index[range(0,11)]).drop(df_usa.columns[range(10,15)], axis=1)

# %%
# rename columns
final_df.rename(columns={0: 'Region Name', 1: 'Region Status', 2: 'ISO', 3: 'ANSI_Letter', 4: 'ANSI_Code'
                         , 5: 'USPS', 6: 'USCG', 7: 'GPO', 8: 'AP', 9: 'Other Abbreviations'}, inplace=True)

# %%
# reset index of rows
final_df.reset_index(drop=True)
# Out:
#                                Region Name                Region Status  \
# 0                 United States of America                Federal state
# 1                                  Alabama                        State
# 2                                   Alaska                        State
# 3                                  Arizona                        State
# 4                                 Arkansas                        State
# 5                               California                        State
# 6                                 Colorado                        State
# 7                              Connecticut                        State
# 8                                 Delaware                        State
# 9                     District of Columbia             Federal district
# 10                                 Florida                        State
# 11                                 Georgia                        State
# 12                                  Hawaii                        State
# 13                                   Idaho                        State
# 14                                Illinois                        State
# 15                                 Indiana                        State
# 16                                    Iowa                        State
# 17                                  Kansas                        State
# 18                                Kentucky         State (Commonwealth)
# 19                               Louisiana                        State
# 20                                   Maine                        State
# 21                                Maryland                        State
# 22                           Massachusetts         State (Commonwealth)
# 23                                Michigan                        State
# 24                               Minnesota                        State
# 25                             Mississippi                        State
# 26                                Missouri                        State
# 27                                 Montana                        State
# 28                                Nebraska                        State
# 29                                  Nevada                        State
# ..                                     ...                          ...
# 48                              Washington                        State
# 49                           West Virginia                        State
# 50                               Wisconsin                        State
# 51                                 Wyoming                        State
# 52                          American Samoa     Insular area (Territory)
# 53                                    Guam     Insular area (Territory)
# 54                Northern Mariana Islands  Insular area (Commonwealth)
# 55                             Puerto Rico     Insular area (Territory)
# 56                     U.S. Virgin Islands     Insular area (Territory)
# 57             U.S. Minor Outlying Islands                Insular areas
# 58                            Baker Island                       island
# 59                          Howland Island                       island
# 60                           Jarvis Island                       island
# 61                          Johnston Atoll                        atoll
# 62                            Kingman Reef                        atoll
# 63                          Midway Islands                        atoll
# 64                          Navassa Island                       island
# 65                        Palmyra Atoll[4]                     atoll[4]
# 66                             Wake Island                        atoll
# 67                              Micronesia      Freely associated state
# 68                        Marshall Islands      Freely associated state
# 69                                   Palau      Freely associated state
# 70         U.S. Armed Forces – Americas[5]        US military mail code
# 71           U.S. Armed Forces – Europe[6]        US military mail code
# 72          U.S. Armed Forces – Pacific[7]        US military mail code
# 73                Northern Mariana Islands      Obsolete postal code[8]
# 74                       Panama Canal Zone         Obsolete postal code
# 75                                Nebraska      Obsolete postal code[9]
# 76                      Philippine Islands         Obsolete postal code
# 77  Trust Territory of the Pacific Islands         Obsolete postal code
#
#                  ISO ANSI_Letter ANSI_Code USPS USCG     GPO      AP  \
# 0         US USA 840          US        00  NaN  NaN    U.S.    U.S.
# 1              US-AL          AL        01   AL   AL    Ala.    Ala.
# 2              US-AK          AK        02   AK   AK  Alaska  Alaska
# 3              US-AZ          AZ        04   AZ   AZ   Ariz.   Ariz.
# 4              US-AR          AR        05   AR   AR    Ark.    Ark.
# 5              US-CA          CA        06   CA   CF  Calif.  Calif.
# 6              US-CO          CO        08   CO   CL   Colo.   Colo.
# 7              US-CT          CT        09   CT   CT   Conn.   Conn.
# 8              US-DE          DE        10   DE   DL    Del.    Del.
# 9              US-DC          DC        11   DC   DC    D.C.    D.C.
# 10             US-FL          FL        12   FL   FL    Fla.    Fla.
# 11             US-GA          GA        13   GA   GA     Ga.     Ga.
# 12             US-HI          HI        15   HI   HA  Hawaii  Hawaii
# 13             US-ID          ID        16   ID   ID   Idaho   Idaho
# 14             US-IL          IL        17   IL   IL    Ill.    Ill.
# 15             US-IN          IN        18   IN   IN    Ind.    Ind.
# 16             US-IA          IA        19   IA   IA    Iowa    Iowa
# 17             US-KS          KS        20   KS   KA   Kans.    Kan.
# 18             US-KY          KY        21   KY   KY     Ky.     Ky.
# 19             US-LA          LA        22   LA   LA     La.     La.
# 20             US-ME          ME        23   ME   ME   Maine   Maine
# 21             US-MD          MD        24   MD   MD     Md.     Md.
# 22             US-MA          MA        25   MA   MS   Mass.   Mass.
# 23             US-MI          MI        26   MI   MC   Mich.   Mich.
# 24             US-MN          MN        27   MN   MN   Minn.   Minn.
# 25             US-MS          MS        28   MS   MI   Miss.   Miss.
# 26             US-MO          MO        29   MO   MO     Mo.     Mo.
# 27             US-MT          MT        30   MT   MT   Mont.   Mont.
# 28             US-NE          NE        31   NE   NB   Nebr.    Neb.
# 29             US-NV          NV        32   NV   NV    Nev.    Nev.
# ..               ...         ...       ...  ...  ...     ...     ...
# 48             US-WA          WA        53   WA   WN   Wash.   Wash.
# 49             US-WV          WV        54   WV   WV  W. Va.   W.Va.
# 50             US-WI          WI        55   WI   WS    Wis.    Wis.
# 51             US-WY          WY        56   WY   WY    Wyo.    Wyo.
# 52  AS ASM 016 US-AS          AS        60   AS   AS    A.S.     NaN
# 53  GU GUM 316 US-GU          GU        66   GU   GU    Guam     NaN
# 54  MP MNP 580 US-MP          MP        69   MP   CM    M.P.     NaN
# 55  PR PRI 630 US-PR          PR        72   PR   PR    P.R.     NaN
# 56  VI VIR 850 US-VI          VI        78   VI   VI    V.I.     NaN
# 57  UM UMI 581 US-UM          UM        74  NaN  NaN     NaN     NaN
# 58             UM-81         NaN        81  NaN  NaN     NaN     NaN
# 59             UM-84         NaN        84  NaN  NaN     NaN     NaN
# 60             UM-86         NaN        86  NaN  NaN     NaN     NaN
# 61             UM-67         NaN        67  NaN  NaN     NaN     NaN
# 62             UM-89         NaN        89  NaN  NaN     NaN     NaN
# 63             UM-71         NaN        71  NaN  NaN     NaN     NaN
# 64             UM-76         NaN        76  NaN  NaN     NaN     NaN
# 65             UM-95         NaN        95  NaN  NaN     NaN     NaN
# 66             UM-79         NaN        79  NaN  NaN     NaN     NaN
# 67        FM FSM 583          FM        64   FM  NaN     NaN     NaN
# 68        MH MHL 584          MH        68   MH  NaN     NaN     NaN
# 69        PW PLW 585          PW        70   PW  NaN     NaN     NaN
# 70               NaN         NaN       NaN   AA  NaN     NaN     NaN
# 71               NaN         NaN       NaN   AE  NaN     NaN     NaN
# 72               NaN         NaN       NaN   AP  NaN     NaN     NaN
# 73               NaN         NaN       NaN   CM  NaN     NaN     NaN
# 74        PZ PCZ 594         NaN       NaN   CZ  NaN     NaN     NaN
# 75               NaN         NaN       NaN   NB  NaN     NaN     NaN
# 76    PH PHL 608[10]         NaN       NaN   PI  NaN     NaN     NaN
# 77        PC PCI 582         NaN       NaN   TT  NaN     NaN     NaN
#
#    Other Abbreviations
# 0               U.S.A.
# 1                  NaN
# 2                Alas.
# 3                  Az.
# 4                  NaN
# 5            Ca., Cal.
# 6                 Col.
# 7                  Ct.
# 8                  De.
# 9           Wash. D.C.
# 10          Fl., Flor.
# 11                 NaN
# 12                H.I.
# 13           Id., Ida.
# 14   Il., Ills., Ill's
# 15                 In.
# 16        Ia., Ioa.[1]
# 17            Ks., Ka.
# 18         Ken., Kent.
# 19                 NaN
# 20                 Me.
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 Mn.
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 Nv.
# ..                 ...
# 48         Wa., Wn.[2]
# 49      W.V., W. Virg.
# 50          Wi., Wisc.
# 51                 Wy.
# 52                 NaN
# 53                 NaN
# 54                 NaN
# 55                 NaN
# 56            U.S.V.I.
# 57                 NaN
# 58               XB[3]
# 59               XH[3]
# 60               XQ[3]
# 61               XU[3]
# 62               XM[3]
# 63               QM[3]
# 64               XV[3]
# 65               XL[3]
# 66               QW[3]
# 67                 NaN
# 68                 NaN
# 69                 NaN
# 70                 NaN
# 71                 NaN
# 72                 NaN
# 73                 NaN
# 74                 NaN
# 75                 NaN
# 76                 NaN
# 77                 NaN
#
# [78 rows x 10 columns]
